# %%
import pandas as pd
import numpy as np
import requests
import json
import pandas as pd
from itertools import tee

# %%
df = pd.read_csv("Clusters+vert_cercanos.csv", delimiter=",")

# %%
df
# Out:
#      Unnamed: 0         x          y  index_vertice_cercano  LATITUD  \
# 0             0  4.124433 -73.627487                  33483    4.124
# 1             1  4.118694 -73.563922                  37514    4.119
# 2             2  4.075202 -73.672954                  52077    4.075
# 3             3  4.153048 -73.599674                  11110    4.153
# 4             4  4.148361 -73.613292                  14637    4.148
# ..          ...       ...        ...                    ...      ...
# 195         195  4.158273 -73.651119                   7341    4.158
# 196         196  4.103017 -73.659508                  45497    4.103
# 197         197  4.155809 -73.632643                   8546    4.156
# 198         198  4.136147 -73.609554                  23612    4.136
# 199         199  4.119560 -73.609358                  37039    4.120
#
#       LONGITUD  distancia_h
# 0   -73.627545     0.048541
# 1   -73.563647     0.045658
# 2   -73.672891     0.023477
# ...

# %%
df_colegios = pd.read_csv("Colegios_oficiales.csv", delimiter=";")

# %%
array_idsede=df_colegios.id_sede.values

# %%
df2=df.copy(deep=True)

# %%
for col_name in array_idsede:
    df2[col_name] = None

# %%
for col_name in array_idsede2:
    df2[col_name] = None

# %%
df2 = df2.drop(array_idsede2, axis=1)

# %%
df_colegios
# Out:
#      id_sede   latitud   longitud
# 0        827  4.123157 -73.541060
# 1        937  4.147969 -73.643800
# 2        945  4.140322 -73.622633
# 3        946  4.131999 -73.635603
# 4        961  4.109037 -73.652828
# ..       ...       ...        ...
# 158    82627  4.134287 -73.611144
# 159    85626  3.981392 -73.237248
# 160    85906  4.139800 -73.614421
# 161    86871  3.981392 -73.237248
# 162    87062  3.981392 -73.237248
#
# [163 rows x 3 columns]

# %%
#Se quita por motivos de seguridad
key_API_google=""

# %%
origenes=[]
DENUEVO['pair_orig']=DENUEVO['Latitud_NS'].astype(str)+"%2C"+DENUEVO['Longitud_NS'].astype(str)

# %%
origenes = [row['LATITUD'].astype(str)+"%2C"+row['LONGITUD'].astype(str) for index, row in df.iterrows()]

# %%
destinos = [row['latitud'].astype(str)+"%2C"+row['longitud'].astype(str) for index, row in df_colegios.iterrows()]

# %%
destinos
# Out:
# ['4.123157307%2C-73.54105965',
#  '4.147969444%2C-73.6438',
#  '4.140322222%2C-73.62263333',
#  '4.13199908%2C-73.63560324',
#  '4.109037352%2C-73.65282838',
#  '4.073460215%2C-73.67090286',
#  '4.143086222%2C-73.58588198',
#  '4.097763049%2C-73.62964022',
#  '4.143867%2C-73.630029',
#  '4.118373908%2C-73.6004798',
#  '4.118373908%2C-73.6004798',
#  '3.981392%2C-73.237248',
#  '3.981392%2C-73.237248',
#  '4.139620352%2C-73.60787728',
#  '4.076590072%2C-73.67337136',
#  '4.109925749%2C-73.64888105',
#  '4.140976696%2C-73.59018497',
#  '4.127289714%2C-73.63696281',
#  '4.136205842%2C-73.63441754',
#  '3.981392%2C-73.237248',
#  '4.122547222%2C-73.63390278',
#  '4.151222%2C-73.613112',
#  '4.12824515%2C-73.58819413',
#  '4.159003154%2C-73.65173186',
#  '4.13636201%2C-73.62455921',
#  '4.160285%2C-73.645764',
#  '3.981392%2C-73.237248',
#  '3.981392%2C-73.237248',
#  '4.122995054%2C-73.54173279',
#  '4.136155543%2C-73.63265483',
#  '3.981392%2C-73.237248',
# ...

# %%
origenes
# Out:
# ['4.124432932948718%2C-73.62748715871795',
#  '4.118693924058824%2C-73.56392190735293',
#  '4.075201501967742%2C-73.6729542432258',
#  '4.153048165722222%2C-73.59967378',
#  '4.148360620941176%2C-73.61329178294118',
#  '4.105292071636364%2C-73.65362448',
#  '4.1393397436875%2C-73.638022381875',
#  '4.119413893842105%2C-73.59579037631579',
#  '4.120591631818182%2C-73.53608037090909',
#  '4.161972255%2C-73.65144976060606',
#  '4.142513901102564%2C-73.58422465974358',
#  '4.0635941438181815%2C-73.50386596272728',
#  '4.0569697906%2C-73.59781528',
#  '4.12886386688%2C-73.6121985376',
#  '4.081513973333333%2C-73.69717485041667',
#  '4.079801727%2C-73.70425134666667',
#  '4.104822860625%2C-73.6234973975',
#  '4.15245332937931%2C-73.63068707034483',
#  '4.121572563125%2C-73.64667114125',
#  '4.060175117269231%2C-73.67260199461538',
#  '4.125357067630435%2C-73.54822033673913',
#  '4.079279571567568%2C-73.66977230054054',
#  '4.134051636761905%2C-73.62016046547619',
# ...

# %%
len(todas_solicitudes[0])
# Out:
# 163

# %%
todas_solicitudes=[]
for i in range(len(origenes)):
    solicitudes=[]
    for j in range(len(destinos)):
        solicitud="https://maps.googleapis.com/maps/api/distancematrix/json?destinations="+destinos[j]+"&origins="+origenes[i]+"&key="+key_API_google
        solicitudes.append(solicitud)
    todas_solicitudes.append(solicitudes)

# %%
todas_solicitudes2 = pd.DataFrame(todas_solicitudes)

# %%
def solicitud_maps(url):
    try:
        payload = {}
        headers = {}
        response = requests.request("GET", url, headers=headers, data=payload)
        x = response.json()
        drive_time_seconds = x['rows'][0]['elements'][0]['duration']['value']
        distance_meters = x['rows'][0]['elements'][0]['distance']['value']
        return [drive_time_seconds, distance_meters]
    except KeyError:
        return 0

# %%
df2[827] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[0]), axis=1)

# %%
df2[937] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[1]), axis=1)
df2[945] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[2]), axis=1)
df2[946] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[3]), axis=1)
df2[961] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[4]), axis=1)

# %%
df2[969] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[5]), axis=1)
df2[970] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[6]), axis=1)
df2[971] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[7]), axis=1)
df2[3876] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[8]), axis=1)
df2[4067] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[9]), axis=1)
df2[4068] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[10]), axis=1)
df2[4174] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[11]), axis=1)
df2[4230] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[12]), axis=1)
df2[4231] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[13]), axis=1)
df2[5409] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[14]), axis=1)

# %%
df2[5888] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[16]), axis=1)
df2[6439] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[17]), axis=1)
df2[6440] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[18]), axis=1)
df2[6449] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[19]), axis=1)
df2[6472] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[20]), axis=1)
df2[6473] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[21]), axis=1)
df2[6474] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[22]), axis=1)
df2[6617] = todas_solicitudes2.apply(lambda x: solicitud_maps(x
= todas_solicitudes2.apply(lambda x: solicitud_maps(x[109]), axis=1)
df2[55535] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[110]), axis=1)
df2[55549] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[111]), axis=1)
df2[55550] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[112]), axis=1)
df2[55558] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[113]), axis=1)
df2[55579] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[114]), axis=1)
df2[55591] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[115]), axis=1)
df2[58580] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[116]), axis=1)
df2[58877] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[117]), axis=1)
df2[58884] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[118]), axis=1)
df2[60967] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[119]), axis=1)
df2[60979] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[120]), axis=1)
df2[61175] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[121]), axis=1)
df2[62527] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[122]), axis=1)
df2[62528] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[123]), axis=1)
df2[63981] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[124]), axis=1)
df2[65066] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[125]), axis=1)
df2[66136] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[126]), axis=1)
df2[66299] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[127]), axis=1)
df2[66323] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[128]), axis=1)
df2[66324] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[129]), axis=1)
df2[66325] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[130]), axis=1)
df2[66341] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[131]), axis=1)
df2[69339] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[132]), axis=1)
df2[69481] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[133]), axis=1)
df2[69482] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[134]), axis=1)

# %%
df2[71574] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[135]), axis=1)
df2[71575] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[136]), axis=1)
df2[71576] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[137]), axis=1)
df2[71584] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[138]), axis=1)
df2[71615] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[139]), axis=1)
df2[71616] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[140]), axis=1)
df2[71617] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[141]), axis=1)
df2[74882] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[142]), axis=1)
df2[74897] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[143]), axis=1)
df2[74898] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[144]), axis=1)
df2[77000] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[145]), axis=1)
df2[77120] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[146]), axis=1)
df2[77121] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[147]), axis=1)
df2[77129] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[148]), axis=1)
df2[77160] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[149]), axis=1)
df2[77161] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[150]), axis=1)
df2[80410] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[151]), axis=1)
df2[81555] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[152]), axis=1)
df2[82443] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[153]), axis=1)
df2[82576] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[154]), axis=1)
df2[82577] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[155]), axis=1)
df2[82595] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[156]), axis=1)
df2[82596] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[157]), axis=1)
df2[82627] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[158]), axis=1)
df2[85626] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[159]), axis=1)
df2[85906] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[160]), axis=1)
df2[86871] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[161]), axis=1)
df2[87062] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[162]), axis=1)

# %%
df2[827]
# Out:
# 0      [1623, 11943]
# 1        [783, 5541]
# 2      [2358, 20737]
# 3       [1338, 9636]
# 4       [1160, 9432]
#            ...
# 195    [1911, 14381]
# 196    [1977, 17208]
# 197    [1547, 11967]
# 198     [1168, 9322]
# 199    [1395, 11652]
# Name: 827, Length: 200, dtype: object

# %%
df2.to_csv("FINAL2.csv",index=True)

# %%
df2
# Out:
#      Unnamed: 0         x          y  index_vertice_cercano  LATITUD  \
# 0             0  4.124433 -73.627487                  33483    4.124
# 1             1  4.118694 -73.563922                  37514    4.119
# 2             2  4.075202 -73.672954                  52077    4.075
# 3             3  4.153048 -73.599674                  11110    4.153
# 4             4  4.148361 -73.613292                  14637    4.148
# ..          ...       ...        ...                    ...      ...
# 195         195  4.158273 -73.651119                   7341    4.158
# 196         196  4.103017 -73.659508                  45497    4.103
# 197         197  4.155809 -73.632643                   8546    4.156
# 198         198  4.136147 -73.609554                  23612    4.136
# 199         199  4.119560 -73.609358                  37039    4.120
#
#       LONGITUD  distancia_h            827            937            945  ...  \
# ...

# %%
array_idsede
# Out:
# array([  827,   937,   945,   946,   961,   969,   970,   971,  3876,
#         4067,  4068,  4174,  4230,  4231,  5409,  5588,  5888,  6439,
#         6440,  6449,  6472,  6473,  6474,  6617,  9710,  9711,  9726,
#        10827, 10887, 11756, 11757, 11758, 15123, 15147, 17213, 17225,
#        17323, 17343, 17359, 17360, 17379, 17380, 20609, 20610, 20622,
#        20623, 20624, 22639, 22783, 22798, 25819, 27262, 27943, 28069,
#        28116, 28117, 28118, 31119, 31422, 31433, 32521, 32522, 33473,
#        33491, 33585, 33609, 33624, 35091, 36695, 36974, 38150, 38534,
#        39041, 39156, 39166, 39193, 39194, 39357, 42458, 42459, 42470,
#        42471, 42472, 44022, 44499, 44622, 44623, 44624, 44633, 44634,
#        44658, 44659, 44675, 44676, 44677, 44825, 47941, 47942, 49556,
#        50086, 50105, 50131, 50132, 50133, 53111, 53406, 53407, 53419,
#        54504, 55534, 55535, 55549, 55550, 55558, 55579, 55591, 58580,
# ...

# %%
df3=df2.copy(deep=True)

# %%
df3 = df3.drop(array_idsede, axis=1)

# %%
for col in array_idsede:
    df3[col] = df2[col].apply(lambda x: x[0])

# %%
df3
# Out:
#      Unnamed: 0         x          y  index_vertice_cercano  LATITUD  \
# 0             0  4.124433 -73.627487                  33483    4.124
# 1             1  4.118694 -73.563922                  37514    4.119
# 2             2  4.075202 -73.672954                  52077    4.075
# 3             3  4.153048 -73.599674                  11110    4.153
# 4             4  4.148361 -73.613292                  14637    4.148
# ..          ...       ...        ...                    ...      ...
# 195         195  4.158273 -73.651119                   7341    4.158
# 196         196  4.103017 -73.659508                  45497    4.103
# 197         197  4.155809 -73.632643                   8546    4.156
# 198         198  4.136147 -73.609554                  23612    4.136
# 199         199  4.119560 -73.609358                  37039    4.120
#
#       LONGITUD  distancia_h   827   937   945  ...  82443  82576  82577  \
# ...

# %%
df3.to_csv("TIEMPOS_VIAJE_SEG_CLUSTERS_COLEGIOSOFICIALES.csv",index=True)

# %%
df4=df2.copy(deep=True)

# %%
df4 = df4.drop(array_idsede, axis=1)

# %%
for col in array_idsede:
    df4[col] = df2[col].apply(lambda x: x[1])

# %%
df4
# Out:
#      Unnamed: 0         x          y  index_vertice_cercano  LATITUD  \
# 0             0  4.124433 -73.627487                  33483    4.124
# 1             1  4.118694 -73.563922                  37514    4.119
# 2             2  4.075202 -73.672954                  52077    4.075
# 3             3  4.153048 -73.599674                  11110    4.153
# 4             4  4.148361 -73.613292                  14637    4.148
# ..          ...       ...        ...                    ...      ...
# 195         195  4.158273 -73.651119                   7341    4.158
# 196         196  4.103017 -73.659508                  45497    4.103
# 197         197  4.155809 -73.632643                   8546    4.156
# 198         198  4.136147 -73.609554                  23612    4.136
# 199         199  4.119560 -73.609358                  37039    4.120
#
#       LONGITUD  distancia_h    827    937    945  ...  82443  82576  82577  \
# ...

# %%
df4.to_csv("DISTANCIAS_METROS_CLUSTERS_COLEGIOSOFICIALES.csv",index=True)
