# %%
import pandas as pd
import numpy as np
import requests
import json
import pandas as pd
from itertools import tee

# %%
df = pd.read_csv("Clusters+vert_cercanos.csv", delimiter=",")

# %%
df_seguridad_policia = pd.read_csv("seguridad_policia_oficiales.csv", delimiter=";")

# %%
df_seguridad_policia
# Out:
#     Id  Latitud_seguridad_policia  Longitud_seguridad_policia
# 0    1                   4.167179                  -73.623657
# 1    2                   4.123192                  -73.577690
# 2    3                   4.148795                  -73.634969
# 3    4                   4.077741                  -73.670454
# 4    5                   4.058403                  -73.672695
# 5    6                   4.156303                  -73.631032
# 6    7                   4.121043                  -73.642440
# 7    8                   4.122414                  -73.632141
# 8    9                   4.165158                  -73.641056
# 9   10                   4.136793                  -73.645865
# 10  11                   4.121857                  -73.533173
# 11  12                   4.142797                  -73.641897
# 12  13                   4.140720                  -73.618162

# %%
array_id=df_seguridad_policia.Id.values

# %%
df2=df.copy(deep=True)

# %%
for col_name in array_id:
    df2[col_name] = None

# %%
df2
# Out:
#      Unnamed: 0         x          y  index_vertice_cercano  LATITUD  \
# 0             0  4.124433 -73.627487                  33483    4.124
# 1             1  4.118694 -73.563922                  37514    4.119
# 2             2  4.075202 -73.672954                  52077    4.075
# 3             3  4.153048 -73.599674                  11110    4.153
# 4             4  4.148361 -73.613292                  14637    4.148
# ..          ...       ...        ...                    ...      ...
# 195         195  4.158273 -73.651119                   7341    4.158
# 196         196  4.103017 -73.659508                  45497    4.103
# 197         197  4.155809 -73.632643                   8546    4.156
# 198         198  4.136147 -73.609554                  23612    4.136
# 199         199  4.119560 -73.609358                  37039    4.120
#
#       LONGITUD  distancia_h              1              2              3  \
# 0   -73.627545     0.048541   [1125, 7201]    [882, 6651]    [768, 4793]
# 1   -73.563647     0.045658  [1502, 11968]    [301, 2471]  [1238, 10254]
# 2   -73.672891     0.023477  [1562, 12948]  [1726, 15601]  [1204, 10539]
# 3   -73.599651     0.005913   [1202, 6353]   [1038, 8114]    [938, 4639]
# 4   -73.613417     0.042406    [850, 4521]    [905, 7866]    [635, 2997]
# ..         ...          ...            ...            ...            ...
# 195 -73.651163     0.030774    [549, 3951]  [1517, 11468]    [462, 2773]
# 196 -73.659841     0.036985   [1151, 9001]  [1315, 11654]    [794, 6593]
# 197 -73.632766     0.025231    [287, 1709]  [1275, 10442]    [268, 1094]
# 198 -73.609601     0.017196   [1016, 5948]    [691, 4715]    [752, 4233]
# 199 -73.609399     0.049086   [1414, 9551]    [726, 4647]   [1056, 7143]
#
#                  4              5              6              7  \
# 0     [1124, 8985]  [1456, 14045]   [1297, 8826]    [487, 2743]
# 1    [1877, 17049]  [1884, 19043]  [1675, 13594]  [1390, 12162]
# 2       [152, 537]    [520, 3178]  [1734, 14573]    [791, 7574]
# 3    [1842, 14493]  [2077, 18762]   [1375, 7978]   [1218, 7471]
# 4    [1552, 12071]  [1947, 14795]   [1022, 6146]    [916, 5829]
# ..             ...            ...            ...            ...
# 195  [1504, 12384]  [1898, 15107]    [721, 5576]    [867, 6142]
# 196    [742, 5682]   [1136, 8405]  [1324, 10626]    [381, 3627]
# 197  [1305, 11071]  [1699, 13794]    [460, 3334]    [668, 4829]
# 198  [1496, 12294]  [1732, 16563]   [1189, 7573]    [892, 5387]
# 199  [1398, 11836]  [1403, 14259]  [1586, 11176]    [912, 6949]
#
#                  8              9             10             11  \
# 0      [236, 1253]   [1056, 6208]    [591, 3000]  [1541, 13843]
# 1    [1291, 10401]  [1543, 12348]  [1520, 11365]    [778, 6714]
# 2    [1173, 10042]  [1602, 13328]    [992, 9071]  [2354, 22764]
# 3     [1256, 7845]   [1243, 6733]   [1437, 7216]  [1352, 10865]
# 4      [993, 4979]    [890, 4901]   [1134, 5575]  [1219, 10617]
# ..             ...            ...            ...            ...
# 195    [986, 6157]    [310, 2380]    [765, 5175]  [1851, 15435]
# 196    [763, 6095]   [1192, 9381]    [582, 5125]  [1944, 18817]
# 197    [788, 4845]    [306, 1884]    [824, 3502]  [1590, 13193]
# 198    [822, 4273]   [1057, 6328]    [963, 4868]  [1209, 10464]
# 199    [839, 5179]   [1345, 8558]   [1025, 6556]  [1462, 11141]
#
#                 12             13
# 0      [694, 3448]    [589, 3406]
# 1    [1558, 11722]    [978, 8780]
# 2     [1118, 9550]  [1471, 11975]
# 3     [1238, 5807]    [725, 3377]
# 4      [936, 4166]    [430, 1990]
# ..             ...            ...
# 195    [522, 3947]    [776, 5365]
# 196    [708, 5604]   [1060, 8028]
# 197    [569, 2262]    [515, 3122]
# 198   [1031, 5248]    [307, 1497]
# 199   [1064, 6912]    [878, 5755]
#
# [200 rows x 20 columns]

# %%
#Se quita por motivos de seguridad
key_API_google=""

# %%
#aca origenes son destinos y destinos son origenes por que estamos midiendo cuanto se demora la policia en llegar allá

# %%
origenes = [row['Latitud_seguridad_policia'].astype(str)+"%2C"+row['Longitud_seguridad_policia'].astype(str) for index, row in df_seguridad_policia.iterrows()]

# %%
destinos = [row['LATITUD'].astype(str)+"%2C"+row['LONGITUD'].astype(str) for index, row in df.iterrows()]

# %%
todas_solicitudes=[]
for i in range(len(origenes)):
    solicitudes=[]
    for j in range(len(destinos)):
        solicitud="https://maps.googleapis.com/maps/api/distancematrix/json?destinations="+destinos[j]+"&origins="+origenes[i]+"&key="+key_API_google
        solicitudes.append(solicitud)
    todas_solicitudes.append(solicitudes)

# %%
todas_solicitudes2 = pd.DataFrame(todas_solicitudes)

# %%
todas_solicitudes2
# Out:
#                                                   0    \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   1    \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   2    \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   3    \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   4    \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   5    \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   6    \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   7    \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   8    \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   9    ...  \
# 0   https://maps.googleapis.com/maps/api/distancem...  ...
# 1   https://maps.googleapis.com/maps/api/distancem...  ...
# 2   https://maps.googleapis.com/maps/api/distancem...  ...
# 3   https://maps.googleapis.com/maps/api/distancem...  ...
# 4   https://maps.googleapis.com/maps/api/distancem...  ...
# 5   https://maps.googleapis.com/maps/api/distancem...  ...
# 6   https://maps.googleapis.com/maps/api/distancem...  ...
# 7   https://maps.googleapis.com/maps/api/distancem...  ...
# 8   https://maps.googleapis.com/maps/api/distancem...  ...
# 9   https://maps.googleapis.com/maps/api/distancem...  ...
# 10  https://maps.googleapis.com/maps/api/distancem...  ...
# 11  https://maps.googleapis.com/maps/api/distancem...  ...
# 12  https://maps.googleapis.com/maps/api/distancem...  ...
#
#                                                   190  \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   191  \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   192  \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   193  \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   194  \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   195  \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   196  \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   197  \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   198  \
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
#                                                   199
# 0   https://maps.googleapis.com/maps/api/distancem...
# 1   https://maps.googleapis.com/maps/api/distancem...
# 2   https://maps.googleapis.com/maps/api/distancem...
# 3   https://maps.googleapis.com/maps/api/distancem...
# 4   https://maps.googleapis.com/maps/api/distancem...
# 5   https://maps.googleapis.com/maps/api/distancem...
# 6   https://maps.googleapis.com/maps/api/distancem...
# 7   https://maps.googleapis.com/maps/api/distancem...
# 8   https://maps.googleapis.com/maps/api/distancem...
# 9   https://maps.googleapis.com/maps/api/distancem...
# 10  https://maps.googleapis.com/maps/api/distancem...
# 11  https://maps.googleapis.com/maps/api/distancem...
# 12  https://maps.googleapis.com/maps/api/distancem...
#
# [13 rows x 200 columns]

# %%
def solicitud_maps(url):
    try:
        payload = {}
        headers = {}
        response = requests.request("GET", url, headers=headers, data=payload)
        x = response.json()
        drive_time_seconds = x['rows'][0]['elements'][0]['duration']['value']
        distance_meters = x['rows'][0]['elements'][0]['distance']['value']
        return [drive_time_seconds, distance_meters]
    except KeyError:
        return 0

# %%
todas_solicitudes2[0][1]
# Out:
# 'https://maps.googleapis.com/maps/api/distancematrix/json?destinations=4.124%2C-73.6275454&origins=4.123192212%2C-73.5776895&key=AIzaSyBQ--k3OdbaKcZgTdlJn9i6tWOD803mSbQ'

# %%
transposed_todas_solicitudes2 = todas_solicitudes2.transpose()

# %%
transposed_todas_solicitudes2
# Out:
#                                                     0   \
# 0    https://maps.googleapis.com/maps/api/distancem...
# 1    https://maps.googleapis.com/maps/api/distancem...
# 2    https://maps.googleapis.com/maps/api/distancem...
# 3    https://maps.googleapis.com/maps/api/distancem...
# 4    https://maps.googleapis.com/maps/api/distancem...
# ..                                                 ...
# 195  https://maps.googleapis.com/maps/api/distancem...
# 196  https://maps.googleapis.com/maps/api/distancem...
# 197  https://maps.googleapis.com/maps/api/distancem...
# 198  https://maps.googleapis.com/maps/api/distancem...
# 199  https://maps.googleapis.com/maps/api/distancem...
#
#                                                     1   \
# 0    https://maps.googleapis.com/maps/api/distancem...
# 1    https://maps.googleapis.com/maps/api/distancem...
# 2    https://maps.googleapis.com/maps/api/distancem...
# 3    https://maps.googleapis.com/maps/api/distancem...
# 4    https://maps.googleapis.com/maps/api/distancem...
# ..                                                 ...
# 195  https://maps.googleapis.com/maps/api/distancem...
# 196  https://maps.googleapis.com/maps/api/distancem...
# 197  https://maps.googleapis.com/maps/api/distancem...
# 198  https://maps.googleapis.com/maps/api/distancem...
# 199  https://maps.googleapis.com/maps/api/distancem...
#
#                                                     2   \
# 0    https://maps.googleapis.com/maps/api/distancem...
# 1    https://maps.googleapis.com/maps/api/distancem...
# 2    https://maps.googleapis.com/maps/api/distancem...
# 3    https://maps.googleapis.com/maps/api/distancem...
# 4    https://maps.googleapis.com/maps/api/distancem...
# ..                                                 ...
# 195  https://maps.googleapis.com/maps/api/distancem...
# 196  https://maps.googleapis.com/maps/api/distancem...
# 197  https://maps.googleapis.com/maps/api/distancem...
# 198  https://maps.googleapis.com/maps/api/distancem...
# 199  https://maps.googleapis.com/maps/api/distancem...
#
#                                                     3   \
# 0    https://maps.googleapis.com/maps/api/distancem...
# 1    https://maps.googleapis.com/maps/api/distancem...
# 2    https://maps.googleapis.com/maps/api/distancem...
# 3    https://maps.googleapis.com/maps/api/distancem...
# 4    https://maps.googleapis.com/maps/api/distancem...
# ..                                                 ...
# 195  https://maps.googleapis.com/maps/api/distancem...
# 196  https://maps.googleapis.com/maps/api/distancem...
# 197  https://maps.googleapis.com/maps/api/distancem...
# 198  https://maps.googleapis.com/maps/api/distancem...
# 199  https://maps.googleapis.com/maps/api/distancem...
#
#                                                     4   \
# 0    https://maps.googleapis.com/maps/api/distancem...
# 1    https://maps.googleapis.com/maps/api/distancem...
# 2    https://maps.googleapis.com/maps/api/distancem...
# 3    https://maps.googleapis.com/maps/api/distancem...
# 4    https://maps.googleapis.com/maps/api/distancem...
# ..                                                 ...
# 195  https://maps.googleapis.com/maps/api/distancem...
# 196  https://maps.googleapis.com/maps/api/distancem...
# 197  https://maps.googleapis.com/maps/api/distancem...
# 198  https://maps.googleapis.com/maps/api/distancem...
# 199  https://maps.googleapis.com/maps/api/distancem...
#
#                                                     5   \
# 0    https://maps.googleapis.com/maps/api/distancem...
# 1    https://maps.googleapis.com/maps/api/distancem...
# 2    https://maps.googleapis.com/maps/api/distancem...
# 3    https://maps.googleapis.com/maps/api/distancem...
# 4    https://maps.googleapis.com/maps/api/distancem...
# ..                                                 ...
# 195  https://maps.googleapis.com/maps/api/distancem...
# 196  https://maps.googleapis.com/maps/api/distancem...
# 197  https://maps.googleapis.com/maps/api/distancem...
# 198  https://maps.googleapis.com/maps/api/distancem...
# 199  https://maps.googleapis.com/maps/api/distancem...
#
#                                                     6   \
# 0    https://maps.googleapis.com/maps/api/distancem...
# 1    https://maps.googleapis.com/maps/api/distancem...
# 2    https://maps.googleapis.com/maps/api/distancem...
# 3    https://maps.googleapis.com/maps/api/distancem...
# 4    https://maps.googleapis.com/maps/api/distancem...
# ..                                                 ...
# 195  https://maps.googleapis.com/maps/api/distancem...
# 196  https://maps.googleapis.com/maps/api/distancem...
# 197  https://maps.googleapis.com/maps/api/distancem...
# 198  https://maps.googleapis.com/maps/api/distancem...
# 199  https://maps.googleapis.com/maps/api/distancem...
#
#                                                     7   \
# 0    https://maps.googleapis.com/maps/api/distancem...
# 1    https://maps.googleapis.com/maps/api/distancem...
# 2    https://maps.googleapis.com/maps/api/distancem...
# 3    https://maps.googleapis.com/maps/api/distancem...
# 4    https://maps.googleapis.com/maps/api/distancem...
# ..                                                 ...
# 195  https://maps.googleapis.com/maps/api/distancem...
# 196  https://maps.googleapis.com/maps/api/distancem...
# 197  https://maps.googleapis.com/maps/api/distancem...
# 198  https://maps.googleapis.com/maps/api/distancem...
# 199  https://maps.googleapis.com/maps/api/distancem...
#
#                                                     8   \
# 0    https://maps.googleapis.com/maps/api/distancem...
# 1    https://maps.googleapis.com/maps/api/distancem...
# 2    https://maps.googleapis.com/maps/api/distancem...
# 3    https://maps.googleapis.com/maps/api/distancem...
# 4    https://maps.googleapis.com/maps/api/distancem...
# ..                                                 ...
# 195  https://maps.googleapis.com/maps/api/distancem...
# 196  https://maps.googleapis.com/maps/api/distancem...
# 197  https://maps.googleapis.com/maps/api/distancem...
# 198  https://maps.googleapis.com/maps/api/distancem...
# 199  https://maps.googleapis.com/maps/api/distancem...
#
#                                                     9   \
# 0    https://maps.googleapis.com/maps/api/distancem...
# 1    https://maps.googleapis.com/maps/api/distancem...
# 2    https://maps.googleapis.com/maps/api/distancem...
# 3    https://maps.googleapis.com/maps/api/distancem...
# 4    https://maps.googleapis.com/maps/api/distancem...
# ..                                                 ...
# 195  https://maps.googleapis.com/maps/api/distancem...
# 196  https://maps.googleapis.com/maps/api/distancem...
# 197  https://maps.googleapis.com/maps/api/distancem...
# 198  https://maps.googleapis.com/maps/api/distancem...
# 199  https://maps.googleapis.com/maps/api/distancem...
#
#                                                     10  \
# 0    https://maps.googleapis.com/maps/api/distancem...
# 1    https://maps.googleapis.com/maps/api/distancem...
# 2    https://maps.googleapis.com/maps/api/distancem...
# 3    https://maps.googleapis.com/maps/api/distancem...
# 4    https://maps.googleapis.com/maps/api/distancem...
# ..                                                 ...
# 195  https://maps.googleapis.com/maps/api/distancem...
# 196  https://maps.googleapis.com/maps/api/distancem...
# 197  https://maps.googleapis.com/maps/api/distancem...
# 198  https://maps.googleapis.com/maps/api/distancem...
# 199  https://maps.googleapis.com/maps/api/distancem...
#
#                                                     11  \
# 0    https://maps.googleapis.com/maps/api/distancem...
# 1    https://maps.googleapis.com/maps/api/distancem...
# 2    https://maps.googleapis.com/maps/api/distancem...
# 3    https://maps.googleapis.com/maps/api/distancem...
# 4    https://maps.googleapis.com/maps/api/distancem...
# ..                                                 ...
# 195  https://maps.googleapis.com/maps/api/distancem...
# 196  https://maps.googleapis.com/maps/api/distancem...
# 197  https://maps.googleapis.com/maps/api/distancem...
# 198  https://maps.googleapis.com/maps/api/distancem...
# 199  https://maps.googleapis.com/maps/api/distancem...
#
#                                                     12
# 0    https://maps.googleapis.com/maps/api/distancem...
# 1    https://maps.googleapis.com/maps/api/distancem...
# 2    https://maps.googleapis.com/maps/api/distancem...
# 3    https://maps.googleapis.com/maps/api/distancem...
# 4    https://maps.googleapis.com/maps/api/distancem...
# ..                                                 ...
# 195  https://maps.googleapis.com/maps/api/distancem...
# 196  https://maps.googleapis.com/maps/api/distancem...
# 197  https://maps.googleapis.com/maps/api/distancem...
# 198  https://maps.googleapis.com/maps/api/distancem...
# 199  https://maps.googleapis.com/maps/api/distancem...
#
# [200 rows x 13 columns]

# %%
df2[1] = transposed_todas_solicitudes2.apply(lambda x: solicitud_maps(x[0]), axis=1)

# %%
df2[2] = transposed_todas_solicitudes2.apply(lambda x: solicitud_maps(x[1]), axis=1)
df2[3] = transposed_todas_solicitudes2.apply(lambda x: solicitud_maps(x[2]), axis=1)
df2[4] = transposed_todas_solicitudes2.apply(lambda x: solicitud_maps(x[3]), axis=1)
df2[5] = transposed_todas_solicitudes2.apply(lambda x: solicitud_maps(x[4]), axis=1)
df2[6] = transposed_todas_solicitudes2.apply(lambda x: solicitud_maps(x[5]), axis=1)
df2[7] = transposed_todas_solicitudes2.apply(lambda x: solicitud_maps(x[6]), axis=1)
df2[8] = transposed_todas_solicitudes2.apply(lambda x: solicitud_maps(x[7]), axis=1)
df2[9] = transposed_todas_solicitudes2.apply(lambda x: solicitud_maps(x[8]), axis=1)
df2[10] = transposed_todas_solicitudes2.apply(lambda x: solicitud_maps(x[9]), axis=1)
df2[11] = transposed_todas_solicitudes2.apply(lambda x: solicitud_maps(x[10]), axis=1)
df2[12] = transposed_todas_solicitudes2.apply(lambda x: solicitud_maps(x[11]), axis=1)
df2[13] = transposed_todas_solicitudes2.apply(lambda x: solicitud_maps(x[12]), axis=1)

# %%
df3=df2.copy(deep=True)
df3 = df3.drop(array_id, axis=1)
for col in array_id:
    df3[col] = df2[col].apply(lambda x: x[0])

df3.to_csv("TIEMPOS_VIAJE_SEG_CLUSTERS_SEGURIDAD_POLICIA.csv",index=True)

# %%
df4=df2.copy(deep=True)
df4 = df4.drop(array_id, axis=1)
for col in array_id:
    df4[col] = df2[col].apply(lambda x: x[1])
    
df4.to_csv("DISTANCIAS_METROS_CLUSTERS_SEGURIDAD_POLICIA.csv",index=True)
