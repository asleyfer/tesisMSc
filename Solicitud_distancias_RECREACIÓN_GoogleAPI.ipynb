# %%
import pandas as pd
import numpy as np
import requests
import json
import pandas as pd
from itertools import tee

# %%
df = pd.read_csv("Clusters+vert_cercanos.csv", delimiter=",")

# %%
df_recreacion = pd.read_csv("recreacion_oficiales.csv", delimiter=";")

# %%
df_recreacion
# Out:
#       Id  Latitud_parques  Longitud_parques
# 0      1         4.110251        -73.635458
# 1      2         4.122018        -73.642998
# 2      3         4.138541        -73.583532
# 3      4         4.132750        -73.591418
# 4      5         4.133788        -73.588416
# ..   ...              ...               ...
# 310  311         4.140346        -73.589339
# 311  312         4.136137        -73.589093
# 312  313         4.136345        -73.591004
# 313  314         4.135150        -73.607150
# 314  315         4.121964        -73.635204
#
# [315 rows x 3 columns]

# %%
array_id=df_recreacion.Id.values

# %%
df2=df.copy(deep=True)

# %%
for col_name in array_id:
    df2[col_name] = None

# %%
df2
# Out:
#      Unnamed: 0         x          y  index_vertice_cercano  LATITUD  \
# 0             0  4.124433 -73.627487                  33483    4.124
# 1             1  4.118694 -73.563922                  37514    4.119
# 2             2  4.075202 -73.672954                  52077    4.075
# 3             3  4.153048 -73.599674                  11110    4.153
# 4             4  4.148361 -73.613292                  14637    4.148
# ..          ...       ...        ...                    ...      ...
# 195         195  4.158273 -73.651119                   7341    4.158
# 196         196  4.103017 -73.659508                  45497    4.103
# 197         197  4.155809 -73.632643                   8546    4.156
# 198         198  4.136147 -73.609554                  23612    4.136
# 199         199  4.119560 -73.609358                  37039    4.120
#
#       LONGITUD  distancia_h              1              2              3  ...  \
# ...

# %%
#Se quita por motivos de seguridad
key_API_google=""

# %%
key_API_google2="AIzaSyCoMt_P4lPT-H5dnppxdS5HCJhHfAd8pvs"

# %%
destinos = [row['Latitud_parques'].astype(str)+"%2C"+row['Longitud_parques'].astype(str) for index, row in df_recreacion.iterrows()]

# %%
origenes = [row['LATITUD'].astype(str)+"%2C"+row['LONGITUD'].astype(str) for index, row in df.iterrows()]

# %%
todas_solicitudes=[]
for i in range(len(origenes)):
    solicitudes=[]
    for j in range(len(destinos)):
        solicitud="https://maps.googleapis.com/maps/api/distancematrix/json?destinations="+destinos[j]+"&origins="+origenes[i]+"&key="+key_API_google2
        solicitudes.append(solicitud)
    todas_solicitudes.append(solicitudes)

# %%
todas_solicitudes2 = pd.DataFrame(todas_solicitudes)

# %%
todas_solicitudes2
# Out:
#                                                    0    \
# 0    https://maps.googleapis.com/maps/api/distancem...
# 1    https://maps.googleapis.com/maps/api/distancem...
# 2    https://maps.googleapis.com/maps/api/distancem...
# 3    https://maps.googleapis.com/maps/api/distancem...
# 4    https://maps.googleapis.com/maps/api/distancem...
# ..                                                 ...
# 195  https://maps.googleapis.com/maps/api/distancem...
# 196  https://maps.googleapis.com/maps/api/distancem...
# 197  https://maps.googleapis.com/maps/api/distancem...
# 198  https://maps.googleapis.com/maps/api/distancem...
# 199  https://maps.googleapis.com/maps/api/distancem...
#
#                                                    1    \
# 0    https://maps.googleapis.com/maps/api/distancem...
# 1    https://maps.googleapis.com/maps/api/distancem...
# 2    https://maps.googleapis.com/maps/api/distancem...
# 3    https://maps.googleapis.com/maps/api/distancem...
# ...

# %%
def solicitud_maps(url):
    try:
        payload = {}
        headers = {}
        response = requests.request("GET", url, headers=headers, data=payload)
        x = response.json()
        drive_time_seconds = x['rows'][0]['elements'][0]['duration']['value']
        distance_meters = x['rows'][0]['elements'][0]['distance']['value']
        return [drive_time_seconds, distance_meters]
    except KeyError:
        return 0

# %%
todas_solicitudes2[0][1]
# Out:
# 'https://maps.googleapis.com/maps/api/distancematrix/json?destinations=4.11025113%2C-73.635458&origins=4.119%2C-73.5636471&key=AIzaSyCoMt_P4lPT-H5dnppxdS5HCJhHfAd8pvs'

# %%
df2[1] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[0]), axis=1)
df2[2] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[1]), axis=1)
df2[3] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[2]), axis=1)
df2[4] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[3]), axis=1)
df2[5] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[4]), axis=1)
df2[6] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[5]), axis=1)
df2[7] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[6]), axis=1)
df2[8] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[7]), axis=1)
df2[9] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[8]), axis=1)
df2[10] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[9]), axis=1)

# %%
df2[11] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[10]), axis=1)
df2[12] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[11]), axis=1)
df2[13] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[12]), axis=1)
df2[14] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[13]), axis=1)
df2[15] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[14]), axis=1)
df2[16] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[15]), axis=1)
df2[17] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[16]), axis=1)
df2[18] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[17]), axis=1)
df2[19] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[18]), axis=1)
df2[20] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[19]), axis=1)
df2[21] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[20]), axis=1)
df2[22] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[21]), axis=1)
df2[23] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[22]), axis=1)
df2[24] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[23]), axis=1)
df2[25] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[24]), axis=1)
df2[26] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[25]), axis=1)
df2[27] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[26]), axis=1)
df2[28] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[27]), axis=1)
df2[29] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[28]), axis=1)
df2[30] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[29]), axis=1)

# %%
df2[31] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[30]), axis=1)
df2[32] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[31]), axis=1)
df2[33] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[32]), axis=1)
df2[34] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[33]), axis=1)
df2[35] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[34]), axis=1)
df2[36] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[35]), axis=1)
df2[37] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[36]), axis=1)
df2[38] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[37]), axis=1)
df2[39] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[38]), axis=1)
df2[40] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[39]), axis=1)
df2[41] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[40]), axis=1)
df2[42] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[41]), axis=1)
df2[43] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[42]), axis=1)
df2[44] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[43]), axis=1)
df2[45] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[44]), axis=1)
df2[46] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[45]), axis=1)
df2[47] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[46]), axis=1)
df2[48] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[47]), axis=1)
df2[49] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[48]), axis=1)
df2[50] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[49]), axis=1)

# %%
df2[51] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[50]), axis=1)
df2[52] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[51]), axis=1)
df2[53] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[52]), axis=1)
df2[54] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[53]), axis=1)
df2[55] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[54]), axis=1)
df2[56] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[55]), axis=1)
df2[57] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[56]), axis=1)
df2[58] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[57]), axis=1)
df2[59] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[58]), axis=1)
df2[60] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[59]), axis=1)
df2[61] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[60]), axis=1)
df2[62] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[61]), axis=1)
df2[63] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[62]), axis=1)
df2[64] = todas_solicitudes2.apply(lambda x: solicitud_maps(x
= todas_solicitudes2.apply(lambda x: solicitud_maps(x[241]), axis=1)
df2[243] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[242]), axis=1)
df2[244] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[243]), axis=1)
df2[245] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[244]), axis=1)
df2[246] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[245]), axis=1)
df2[247] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[246]), axis=1)
df2[248] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[247]), axis=1)
df2[249] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[248]), axis=1)
df2[250] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[249]), axis=1)
df2[251] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[250]), axis=1)
df2[252] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[251]), axis=1)
df2[253] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[252]), axis=1)
df2[254] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[253]), axis=1)
df2[255] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[254]), axis=1)
df2[256] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[255]), axis=1)
df2[257] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[256]), axis=1)
df2[258] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[257]), axis=1)
df2[259] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[258]), axis=1)
df2[260] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[259]), axis=1)
df2[261] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[260]), axis=1)
df2[262] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[261]), axis=1)
df2[263] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[262]), axis=1)
df2[264] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[263]), axis=1)
df2[265] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[264]), axis=1)
df2[266] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[265]), axis=1)
df2[267] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[266]), axis=1)
df2[268] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[267]), axis=1)
df2[269] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[268]), axis=1)
df2[270] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[269]), axis=1)

# %%
df2[271] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[270]), axis=1)
df2[272] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[271]), axis=1)
df2[273] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[272]), axis=1)
df2[274] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[273]), axis=1)
df2[275] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[274]), axis=1)
df2[276] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[275]), axis=1)
df2[277] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[276]), axis=1)
df2[278] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[277]), axis=1)
df2[279] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[278]), axis=1)
df2[280] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[279]), axis=1)
df2[281] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[280]), axis=1)
df2[282] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[281]), axis=1)
df2[283] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[282]), axis=1)
df2[284] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[283]), axis=1)
df2[285] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[284]), axis=1)
df2[286] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[285]), axis=1)
df2[287] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[286]), axis=1)
df2[288] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[287]), axis=1)
df2[289] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[288]), axis=1)
df2[290] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[289]), axis=1)
df2[291] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[290]), axis=1)
df2[292] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[291]), axis=1)
df2[293] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[292]), axis=1)
df2[294] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[293]), axis=1)
df2[295] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[294]), axis=1)
df2[296] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[295]), axis=1)
df2[297] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[296]), axis=1)
df2[298] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[297]), axis=1)
df2[299] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[298]), axis=1)
df2[300] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[299]), axis=1)

# %%
df2[301] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[300]), axis=1)
df2[302] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[301]), axis=1)
df2[303] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[302]), axis=1)
df2[304] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[303]), axis=1)
df2[305] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[304]), axis=1)
df2[306] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[305]), axis=1)
df2[307] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[306]), axis=1)
df2[308] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[307]), axis=1)
df2[309] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[308]), axis=1)
df2[310] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[309]), axis=1)
df2[311] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[310]), axis=1)
df2[312] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[311]), axis=1)
df2[313] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[312]), axis=1)
df2[314] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[313]), axis=1)
df2[315] = todas_solicitudes2.apply(lambda x: solicitud_maps(x[314]), axis=1)

# %%
df3=df2.copy(deep=True)
df3 = df3.drop(array_id, axis=1)
for col in array_id:
    df3[col] = df2[col].apply(lambda x: x[0])

df3.to_csv("TIEMPOS_VIAJE_SEG_CLUSTERS_RECREACION.csv",index=True)

# %%
df4=df2.copy(deep=True)
df4 = df4.drop(array_id, axis=1)
for col in array_id:
    df4[col] = df2[col].apply(lambda x: x[1])
    
df4.to_csv("DISTANCIAS_METROS_CLUSTERS_RECREACION.csv",index=True)
